# %% [markdown]
# # **Project Name**    -          Global Terrorism Dataset

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# The Global Terrorism Database (GTD) is a comprehensive and widely referenced data repository that catalogs terrorist events worldwide from 1970 to the present. Managed by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, the GTD serves as a critical resource for researchers, policymakers, and security analysts seeking to understand the patterns and impacts of terrorism.
# Through its extensive data collection and rigorous analysis, the GTD contributes significantly to the discourse on terrorism, offering insights that are crucial for effective policy-making and research. As terrorism continues to evolve, the GTD will remain a key tool for those seeking to comprehend and combat this persistent global challenge.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Global Terrorism Database (GTD) is a comprehensive and widely referenced data repository that catalogs terrorist events worldwide from 1970 to the present. Managed by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, the GTD serves as a critical resource for researchers, policymakers, and security analysts seeking to understand the patterns and impacts of terrorism.
#
# Through its extensive data collection and rigorous analysis, the GTD contributes significantly to the discourse on terrorism, offering insights that are crucial for effective policy-making and research. As terrorism continues to evolve, the GTD will remain a key tool for those seeking to comprehend and combat this persistent global challenge.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To reduce Global Terrorism

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# **GITHUB LINK**
# https://github.com/Abhishekkaithwas/-MODULE-2-GTD-EDA-Submission-.ipynb.git

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# Out:
# <ipython-input-1-954b9a4d2efd>:4: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
filepath="/content/drive/MyDrive/Colab Notebooks/Global Terrorism Data.csv"
dataset=pd.read_csv(filepath, encoding='latin-1')
# Out:
# <ipython-input-4-802b33d17c61>:3: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv(filepath, encoding='latin-1')

# %%
# Importing the dataset
dataset
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(dataset.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset given is a dataset from (UNGTA) United Nation Global Terrorism Analysis , this extensive collection is meticulously curated to offer valuable insights into terrorist activities across the globe.
#
# Insights into the geographic regions affected, including country, region, and city specifics, as well as details about targeted groups or individuals.
#
# Information on the attack methods used, weapons involved, and the nature of the attack (e.g., explosive, incendiary, or armed assault).
#
# Data on casualties, including the number of killed or wounded, and any property damage or ransom demands associated with the attacks.
#
# The above dataset has 181691 rows and 135 columns. There are no mising values and duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
dataset.describe(include='all')
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Eventid              :**a numeric variable in which Incidents from the GTD follows a 12 Digit event ID system.
#
#
# *   First 8 numbers - Date recorded "yyyymmdd"
# *   Last 4 numbers - sequential case number for the given day(0001, 0002, etc).This is "0001" unless there is more than one case occuring on the same date
#
#
# * **iyear              :**This field contains the year in which the incident occurred. In the case of incident(s) occurring over an extended period, the field will record the year when the incident was initiated.
#
# * **imonth               :**This field contains the number of the month in which the incident occurred
#
# * **iday                 :**This field contains the numeric day of the month on which the incident occurred
#
# * **approxdate           :**Whenever the exact date of the incident is not known or remains unclear, this field is used to record the approximate date of the incident
#
# * **extended             :**duration of extended incident.
#
#    1 = "Yes" The duration of an incident extended more than 24 hours.
#
#    0 = "No" The duration of an incident extended less than 24 hours.
#
# * **resolution            :**This field only applies if “Extended Incident?” is “Yes” and records the date in which the incident was resolved (hostages released by perpetrators; hostages killed; successful rescue, etc.)
#
# * **country**, **country_txt** : This field identifies the country or location where the incident occurred. Separatist regions, such as Kashmir, Chechnya, South Ossetia, Transnistria, or Republic of Cabinda, are coded as part of the “home” country.
#
# * **region** : This field identifies the region in which the incident occurred. The regions are divided into the following 12 categories, and dependent on the country coded for the case
#
#
# * **addnotes** : This field is used to capture additional relevant details about the attack
#
#
# * **scite1** :This field cites the first source that was used to compile information on the specific incident.
#
# * **scite2** :This field cites the second source that was used to compile information on the specific incident.
#
# * **scite3** :This field cites the third source that was used to compile information on the specific incident.
#
# * **dbsource** :This field identifies the original data collection effort in which each event was recorded.
#
# * **INT_LOG**        :This variable is based on a comparison between the nationality of the perpetrator group and the location of the attack.
#
# * **INT_IDEO**      :This variable is based on a comparison between the nationality of the perpetrator group and the nationality of the target(s)/victim(s).
#
# * **INT_MISC**  :This variable is based on a comparison between the location of the attack and the nationality of the target(s)/victim(s).
#
# * **INT_ANY**   :International, any of the above.
#
# * **Related**   :When an attack is part of a coordinated, multi-part incident the GTD IDs of the related incidents are listed here, separated by commas

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")
# Out:
# No. of unique values in  eventid is 181691 .
# No. of unique values in  iyear is 47 .
# No. of unique values in  imonth is 13 .
# No. of unique values in  iday is 32 .
# No. of unique values in  approxdate is 2244 .
# No. of unique values in  extended is 2 .
# No. of unique values in  resolution is 1859 .
# No. of unique values in  country is 205 .
# No. of unique values in  country_txt is 205 .
# No. of unique values in  region is 12 .
# No. of unique values in  region_txt is 12 .
# No. of unique values in  provstate is 2855 .
# No. of unique values in  city is 36673 .
# No. of unique values in  latitude is 48322 .
# No. of unique values in  longitude is 48039 .
# No. of unique values in  specificity is 5 .
# No. of unique values in  vicinity is 3 .
# No. of unique values in  location is 44109 .
# No. of unique values in  summary is 112492 .
# No. of unique values in  crit1 is 2 .
# No. of unique values in  crit2 is 2 .
# No. of unique values in  crit3 is 2 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#Incidents occured in year 2017
dataset = dataset[dataset['iyear'] == 2017]

# %%
dataset
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 170340  201612150072   2017       1     2        NaN         1        NaN
# 170669  201612270022   2017       1     3        NaN         0        NaN
# 170697  201612280045   2017       1     1        NaN         0        NaN
# 170698  201612280046   2017       1     1        NaN         0        NaN
# 170794  201701010001   2017       1     1        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country                       country_txt  region  ...  \
# ...

# %%
#Incidents occured in a specific country
dataset_india=dataset[dataset['country_txt']=='India']

# %%
dataset
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 170340  201612150072   2017       1     2        NaN         1        NaN
# 170669  201612270022   2017       1     3        NaN         0        NaN
# 170697  201612280045   2017       1     1        NaN         0        NaN
# 170698  201612280046   2017       1     1        NaN         0        NaN
# 170794  201701010001   2017       1     1        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country                       country_txt  region  ...  \
# ...

# %%
#Count the total number of incidents, or group by specific criteria (e.g., by year, country).
incident_counts = dataset['iyear'].value_counts()
print(incident_counts)
# Out:
# iyear
# 2017    10900
# Name: count, dtype: int64

# %%
#Group the data by certain categories (e.g., attack type, region) and aggregate.
attack_type_counts = dataset.groupby('attacktype1_txt').size()
print(attack_type_counts)
# Out:
# attacktype1_txt
# Armed Assault                          2365
# Assassination                           816
# Bombing/Explosion                      5024
# Facility/Infrastructure Attack          751
# Hijacking                                58
# Hostage Taking (Barricade Incident)      82
# Hostage Taking (Kidnapping)             878
# Unarmed Assault                         101
# Unknown                                 825
# dtype: int64

# %%
#Identify columns with missing values and their counts.
missing_values = dataset.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# approxdate     9213
# resolution    10900
# provstate         2
# latitude         47
# longitude        47
#               ...
# nreleased      9881
# addnotes       8110
# scite2         3824
# scite3         6766
# related        8878
# Length: 93, dtype: int64

# %%
#For non-critical fields, fill missing values with unknown
dataset['approxdate'] = dataset['approxdate'].fillna('Unknown')
# Out:
# <ipython-input-70-dfe5172e97a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['approxdate'] = dataset['approxdate'].fillna('Unknown')

# %%
dataset
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 170340  201612150072   2017       1     2    Unknown         1        NaN
# 170669  201612270022   2017       1     3    Unknown         0        NaN
# 170697  201612280045   2017       1     1    Unknown         0        NaN
# 170698  201612280046   2017       1     1    Unknown         0        NaN
# 170794  201701010001   2017       1     1    Unknown         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31    Unknown         0        NaN
# 181687  201712310029   2017      12    31    Unknown         0        NaN
# 181688  201712310030   2017      12    31    Unknown         0        NaN
# 181689  201712310031   2017      12    31    Unknown         0        NaN
# 181690  201712310032   2017      12    31    Unknown         0        NaN
#
#         country                       country_txt  region  ...  \
# ...

# %%
dataset.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
# Check for duplicates
dataset.drop_duplicates(inplace=True)
# Out:
# <ipython-input-73-b4e642149113>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop_duplicates(inplace=True)

# %%
# Create a box plot of the INT_LOG feature
sns.boxplot(x="INT_LOG", data=dataset)

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10900 entries, 170340 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 11.3+ MB

# %%
#Use basic plotting libraries like Matplotlib or Seaborn to visualize the data.
incident_counts = dataset['iyear'].value_counts()
incident_counts.plot(kind='bar')
plt.title('Number of Incidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.   Whopping Incidents occured in a single year 2017 were:-  *1660*
# 2.   Incidents occured in a specific country(India) alone were:- *92*
# 3.   Types of incidents took place till now
#
#     Armed Assault :-                         2365
#
#     Assassination :-                          816
#
#     Bombing/Explosion  :-                    5024
#
#     Facility/Infrastructure Attack :-         751
#
#     Hijacking :-                               58
#
#     Hostage Taking (Barricade Incident):-      82
#
#     Hostage Taking (Kidnapping) :-            878
#
#     Unarmed Assault :-                         101
#
#     Unknown         :-                        825
#
# 4.    Missing values in the data
#
#     approxdate     9213
#
#     resolution    10900
#
#     provstate         2
#
#     latitude         47
#
#     longitude        47
#
#     nreleased      9881
#
#     addnotes       8110
#
#     scite2         3824
#
#     scite3         6766
#
#     related        8878

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Pie chart on attack type counts

# %%
# Chart - 1 visualization code
attack_type_counts = dataset.groupby('attacktype1_txt').size()
plt.figure(figsize=(10, 10))
plt.pie(attack_type_counts, labels=attack_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Attack Types in 2017')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose this pie chart to visualize the distribution of attack types in the dataset for the year 2017 because it effectively illustrates the proportion of each attack type relative to the total number of attacks. This allows for a quick and easy understanding of which attack types are most prevalent.
#
# The pie chart is suitable for this specific data and purpose because:
#
# Categorical Data: The 'attacktype1_txt' column contains categorical data (different types of attacks). Pie charts are ideal for visualizing the relative frequencies of categories within a dataset.
# Proportion Visualization: Pie charts excel at showing how each category contributes to the overall whole (in this case, the total number of attacks). The size of each slice directly corresponds to its proportion.
# Easy Interpretation: Pie charts are generally easy to understand, even for audiences without a strong data analysis background, making them effective for conveying the relative importance of different attack types.
# By selecting a pie chart, we can clearly see which attack types are most common, providing valuable insights for understanding the nature of terrorist attacks in 2017. This information could be used to inform counterterrorism strategies, allocate resources, and develop more effective security measures.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most frequent attack type was bombing/explosion (approximately 41%), followed by armed assault (approximately 19%). Facility/Infrastructure attack and assassination were the least frequent. This suggests that security measures and counter-terrorism strategies should prioritize mitigating the risk of bombings and armed assaults. This information can be used to allocate resources and develop targeted interventions to reduce the occurrence of these types of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help in creating a positive business impact. By understanding the most frequent attack types, security agencies and policymakers can:
#
# Develop targeted prevention strategies: For example, increased security measures around potential targets for bombings and stricter control of explosives.
# Allocate resources effectively: Focus resources on areas or types of attacks that are most likely to occur.
# Improve intelligence and response capabilities: Develop better strategies to detect and respond to these specific types of attacks.
# Collaborate with relevant stakeholders: Share insights with other organizations and countries to improve global counter-terrorism efforts.
# Insights that lead to negative growth are not evident from this chart alone. However, it's important to consider potential negative impacts:
#
# Misinterpretation of data: Focusing solely on preventing the most frequent attack types could leave other areas vulnerable.
# Displacement of attacks: Terrorist groups may shift tactics if certain types of attacks become more difficult.
# Increased costs: Implementing new security measures can be expensive, potentially straining resources.
# By carefully considering both the positive and potential negative impacts, informed decisions can be made to create a safer environment and mitigate the risks of terrorism.

# %% [markdown]
# #### Chart - 2 A bar chart showing the average number of casualties (killed and wounded) per attack type for the 5 most frequent attack types.

# %%
# Chart - 2 visualization code
# Filter dataset for the 5 most frequent attack types.
top_attack_types = dataset['attacktype1_txt'].value_counts().nlargest(5).index
filtered_data = dataset[dataset['attacktype1_txt'].isin(top_attack_types)]

# Calculate average casualties per attack type.
average_casualties = filtered_data.groupby('attacktype1_txt')[['nkill', 'nwound']].mean().sum(axis=1)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(average_casualties.index, average_casualties.values)
plt.title('Average Casualties per Attack Type (Top 5)')
plt.xlabel('Attack Type')
plt.ylabel('Average Casualties')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a bar chart to visualize the average number of casualties per attack type for several reasons:
#
# Comparison: Bar charts are excellent for comparing distinct categories, in this case, the different attack types. The height of each bar directly represents the average number of casualties, making it easy to see which attack types are more lethal.
# Focus on limited data: By focusing on the top 5 attack types, we avoid visual clutter and highlight the most impactful categories. This makes the chart easier to interpret and the insights more readily apparent.
# Clear Communication: Bar charts are simple and widely understood, making them effective for communicating the key message – the relative lethality of different attack types. This information is crucial for understanding the impact of terrorism and developing appropriate countermeasures.
# Data Type: We have categorical data (attack types) and numerical data (average casualties), and a bar chart effectively represents this type of data combination.
# This chart helps to understand which attack types are most harmful in terms of casualties. This can inform security strategies, resource allocation, and public awareness campaigns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart visualizing average casualties per attack type for the top 5 most frequent attack types would likely reveal which attack types are the most dangerous in terms of causing casualties (killed and wounded). You could see which attack type has the highest average casualty count. This could be bombing/explosion, as it often results in mass casualties. You might also find a significant difference in the average casualties between different attack types, indicating that some methods are more lethal than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights from the bar chart can definitely help create a positive business impact, particularly for organizations involved in security, counter-terrorism, and risk management.
#
# Here's how:
#
# Resource Allocation: Understanding which attack types are most likely to cause high casualties allows security agencies and policymakers to allocate resources effectively. This could mean investing more in bomb detection and disposal units, strengthening security measures around potential bombing targets, or increasing medical preparedness for mass casualty events.
# Targeted Strategies: The insights can help develop more targeted counter-terrorism strategies. For instance, if bombings are identified as the most lethal attack type, efforts could focus on disrupting the supply chain of explosives, improving intelligence gathering on potential bomb threats, and enhancing public awareness about suspicious activities.
# Risk Assessment and Mitigation: Businesses can use the information to improve their risk assessments and mitigation strategies. For example, if a business operates in an area with a high risk of a particular attack type, they can implement specific security measures to protect their employees and assets.
# However, there could be potential downsides or negative impacts to consider:
#
# Overemphasis on Specific Threats: Focusing solely on the attack types with the highest average casualties could lead to neglecting other threats that might be less lethal but still significant. Terrorist groups might also adapt their tactics and shift to different attack methods if they perceive increased security in certain areas.
# Fear and Panic: Publicly highlighting the most lethal attack types could inadvertently create fear and panic, especially if not accompanied by clear and reassuring communication about security measures and risk mitigation efforts.
# Overall, the insights gained from this analysis can contribute to a positive business impact by facilitating informed decision-making and the development of effective counter-terrorism strategies. However, it's important to maintain a balanced approach, consider potential negative consequences, and adapt strategies as the terrorism landscape evolves.

# %% [markdown]
# #### Chart - 3 A violin plot showing the distribution of the number of people wounded for each attack type

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12, 6))
sns.boxplot(x='attacktype1_txt', y='nkill', data=dataset)
plt.title('Distribution of Casualties by Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Number of Killed')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose a violin plot to visualize the distribution of wounded by attack type for several reasons:
#
# Detailed Distribution: Violin plots not only show the median and quartiles like a box plot but also illustrate the probability density of the data at different values. This gives a more comprehensive understanding of the distribution of casualties for each attack type. You can see the range of casualties, the concentration of values, and potential outliers more clearly.
#
# Comparison: Violin plots allow for easy comparison between different categories (attack types in this case). You can quickly see if certain attack types have a wider spread of casualties, are more skewed, or have different typical casualty numbers.
#
# Handling Large Datasets: Violin plots can handle larger datasets effectively, providing a clear visualization even when there are many data points.
#
# Aesthetics: Violin plots can be visually appealing and engaging, making the data more accessible and interesting for the audience.
#
# By using a violin plot, we can gain a deeper understanding of how the number of wounded varies across different attack types. This information can be valuable for developing targeted response strategies, allocating medical resources, and understanding the overall impact of different attack types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Bombing/Explosion: This attack type likely has the widest distribution and might show a higher number of wounded compared to other attack types. This suggests that bombings can result in a large number of casualties, though there is considerable variation.
# Armed Assault: You might observe a skewed distribution with a longer tail on the higher end, indicating that while most armed assaults result in fewer casualties, some can lead to a significant number of wounded.
# Assassination: This attack type probably has a narrower distribution and a lower median compared to bombings or armed assaults, suggesting that assassinations generally result in fewer wounded individuals.
# Hostage Taking: This category could show a varied distribution, potentially with some outliers, indicating that the number of wounded can fluctuate significantly depending on the specific circumstances of the hostage situation.
# Facility/Infrastructure Attack: This attack type might have a relatively smaller number of wounded compared to others, but it could still show some variation depending on the target and method used

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here are some potential insights
# Bombing/Explosion: This attack type likely has the widest distribution and might show a higher number of killed compared to other attack types. This suggests that bombings can result in a large number of casualties, though there is considerable variation.
# Armed Assault: You might observe a skewed distribution with a longer tail on the higher end, indicating that while most armed assaults result in fewer casualties, some can lead to a significant number of killed.
# Assassination: This attack type probably has a narrower distribution and a lower median compared to bombings or armed assaults, suggesting that assassinations generally result in fewer killed individuals.
# Hostage Taking: This category could show a varied distribution, potentially with some outliers, indicating that the number of killed can fluctuate significantly depending on the specific circumstances of the hostage situation.
# Facility/Infrastructure Attack: This attack type might have a relatively smaller number of killed compared to others, but it could still show some variation depending on the target and method used.

# %% [markdown]
# #### Chart - 4 Histogram to show the distribution of the number of attacks per month

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
plt.hist(dataset['imonth'], bins=12)
plt.title('Distribution of Attacks per Month')
plt.xlabel('Month')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a histogram to show the distribution of attacks per month because:
#
# Distribution Visualization: Histograms are ideal for visualizing the distribution of a single numerical variable, in this case, the month in which attacks occurred. They show the frequency or count of occurrences within different ranges or bins.
#
# Identifying Patterns: By looking at the shape of the histogram, we can identify potential patterns or trends. For example, are attacks more frequent in certain months? Is there a particular time of year when attacks are more common?
#
# Easy Interpretation: Histograms are easy to understand and interpret, even for people without a strong background in data analysis. The bars clearly show the number of attacks in each month, making it straightforward to identify months with higher or lower attack frequencies.
#
# Data Type: The "imonth" variable is numerical and discrete (representing the months of the year), making a histogram a suitable choice for visualizing its distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# You'll likely observe a heavily right-skewed distribution in the histogram of the number of people killed in terrorist attacks. This means that:
#
# Most Attacks Have Few Casualties: The majority of terrorist attacks result in a relatively small number of fatalities. You'll see a tall bar on the left side of the histogram, representing attacks with zero or a very low number of deaths.
# Some Attacks Have High Casualties: There will be a long tail on the right side of the histogram, indicating that a small number of attacks cause a large number of deaths. These are the high-impact, devastating attacks that, while less frequent, contribute significantly to the overall death toll.
# Potential Outliers: You might observe some outliers, which are individual attacks with an extremely high number of fatalities. These could represent mass casualty events or attacks with particularly lethal methods.
# This skewed distribution is a common characteristic of terrorist attack data, reflecting the fact that most attacks are smaller-scale, while a few high-profile attacks cause a disproportionate number of casualties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the gained insights from the histogram showing the distribution of attacks per month could potentially contribute to a positive business impact for various organizations:
#
# Security Agencies: If the histogram reveals certain months with a higher frequency of attacks, security agencies can increase vigilance and preparedness during those periods. This might involve deploying more personnel, intensifying surveillance, or implementing specific security measures based on the types of attacks that are more common during those months.
#
# Tourism and Travel Industry: Understanding the seasonal patterns of attacks can help the tourism and travel industry to better manage risks and advise travelers. They can inform customers about potential threats during specific periods and adjust travel itineraries or security protocols accordingly.
#
# Insurance Companies: Insurance companies can utilize the insights to assess risks and adjust premiums for travel or event insurance policies based on the likelihood of attacks during particular times of the year.
#
# However, there could also be potential negative impacts to consider:
#
# Misinterpretation: It's crucial to avoid overgeneralizing from the data. Even if certain months show a higher attack frequency, it doesn't guarantee that attacks will definitely occur during those times, and it doesn't mean that other months are completely safe.
#
# Economic Impact: Increased security measures or travel advisories during specific periods could negatively impact businesses reliant on tourism or travel during those times. This could lead to reduced revenue and economic slowdown in certain regions.
#
# Social Disruption: Heightened security measures or public anxiety stemming from the awareness of seasonal attack patterns could disrupt normal social activities and create unnecessary fear or tension.
#
# Overall, the insights from the histogram can be valuable for informed decision-making and risk management. However, it's essential to interpret the data cautiously, consider potential negative consequences, and use the information responsibly to enhance security and minimize disruption

# %% [markdown]
# #### Chart - 5 Stacked bar chart

# %%
# Chart - 5 visualization code
# Group data by attack type and success
attack_success = dataset.groupby(['attacktype1_txt', 'success']).size().reset_index(name='count')

# Calculate proportions
attack_success['proportion'] = attack_success.groupby('attacktype1_txt')['count'].transform(lambda x: x / x.sum())

# Create stacked bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x='attacktype1_txt', y='proportion', hue='success', data=attack_success)
plt.title('Proportion of Successful Attacks by Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Proportion')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a stacked bar chart to visualize the proportion of successful attacks by attack type for several reasons:
#
# Comparison of Categories: Stacked bar charts are excellent for comparing proportions across different categories. In this case, we are comparing the success rates of different attack types. The height of each bar segment represents the proportion of successful or unsuccessful attacks for a specific attack type.
#
# Visualizing Proportions: The stacked nature of the chart clearly shows how the proportions of successful and unsuccessful attacks contribute to the whole (100%) for each attack type. This allows for quick visual comparisons of success rates across different categories.
#
# Clear and Informative: Stacked bar charts are generally easy to understand and provide a clear representation of the data. They can effectively highlight differences in success rates between attack types.
#
# Data Type: We have categorical data (attack type) and a binary variable (success or failure of the attack), which is suitable for representation with a stacked bar chart.
#
# By using a stacked bar chart, we can gain insights into the relative success rates of different attack types. This information can be valuable for security agencies and policymakers to understand which attack types pose the greatest threat and to develop targeted countermeasures

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# You might observe the following insights from the stacked bar chart showing the proportion of successful attacks by attack type:
#
# Variation in Success Rates: You'll likely see that different attack types have varying success rates. Some attack types, such as bombings or armed assaults, might have higher success rates compared to others, like hostage-taking or facility/infrastructure attacks.
#
# Impact of Attack Type: The chart can reveal which attack types are more likely to achieve their intended goals. This information can help security agencies understand the effectiveness of different attack methods and prioritize countermeasures accordingly.
#
# Potential Trends: You might notice patterns or trends in the success rates of certain attack types. For example, has the success rate of a particular attack type increased or decreased over time? This could indicate changes in terrorist tactics or security measures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the stacked bar chart showing the proportion of successful attacks by attack type can contribute to a positive business impact in several ways:
#
# Improved Counterterrorism Strategies: Understanding which attack types have higher success rates allows security agencies to prioritize their efforts and develop more targeted countermeasures. For instance, if bombings are found to have a high success rate, resources could be focused on bomb detection, prevention, and response strategies.
#
# Resource Allocation: By identifying attack types with lower success rates, resources can be allocated more efficiently. This might involve reducing investment in countermeasures for less successful attack types and focusing on areas where the risk is higher.
#
# Risk Assessment: Businesses can use the information to assess the risk of different attack types and implement appropriate security measures. This could involve investing in specific security technologies, training staff on threat awareness, or developing emergency response plans tailored to the most likely attack types.
#
# However, there are potential downsides and negative growth implications to consider:
#
# Shifting Tactics: Terrorist groups might adapt their tactics if they become aware that certain attack types are less successful. They could shift to different methods or targets, potentially rendering existing countermeasures less effective.
# False Sense of Security: Focusing solely on the success rates of attack types could lead to neglecting other important factors, such as the potential for large-scale casualties or the psychological impact of terrorism, even if an attack is ultimately unsuccessful.
# Overlooking Emerging Threats: The data might not capture new or evolving attack types that could pose a significant risk in the future. Relying solely on historical data could lead to preparedness gaps.
# In conclusion, while the insights from the stacked bar chart can be valuable for enhancing security and counterterrorism efforts, it's essential to consider the potential for negative consequences and maintain a flexible and adaptable approach to address the evolving nature of terrorism.

# %% [markdown]
# #### Chart - 6 Pair plot

# %%
# Chart - 6 visualization code
# Select columns for correlation analysis
cols_for_correlation = ['nperps', 'nperpcap', 'nkill', 'nwound']

# Calculate correlation matrix
corr_matrix = dataset[cols_for_correlation].corr()

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a correlation heatmap for this dataset because:
#
# Exploring Relationships: Correlation heatmaps are excellent for visualizing the relationships between multiple numerical variables. In this case, we want to understand how variables like the number of perpetrators, captured perpetrators, and casualties relate to each other.
#
# Identifying Patterns: The heatmap uses color coding to represent the strength and direction of correlations. This makes it easy to quickly identify strong positive or negative correlations between variables.
#
# Multicollinearity Detection: If you're planning to build a machine learning model, correlation heatmaps can help detect multicollinearity, which is the presence of strong correlations between predictor variables. This can be problematic for certain models, and the heatmap can help identify potential issues.
#
# Data Exploration: Even without a specific modeling goal, correlation heatmaps are a valuable tool for data exploration and understanding the underlying relationships in your data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# You might observe the following insights from the correlation heatmap using the columns nperps, nperpcap, nkill, and nwound:
#
# Positive Correlation between Perpetrators and Casualties: You might find a positive correlation between the number of perpetrators involved in an attack (nperps) and the number of people killed (nkill) or wounded (nwound). This suggests that attacks with more perpetrators tend to be more lethal.
# Negative Correlation between Perpetrators and Capture: There could be a negative correlation between the number of perpetrators (nperps) and the number of perpetrators captured (nperpcap). This might indicate that attacks involving more individuals are more difficult for authorities to apprehend all the perpetrators.
# Correlation between Killed and Wounded: You'll probably see a strong positive correlation between the number of people killed (nkill) and the number of people wounded (nwound). This is expected, as attacks that result in fatalities often also cause injuries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the correlation heatmap can potentially contribute to a positive business impact for various organizations:
#
# Law Enforcement and Security Agencies: Understanding the relationship between the number of perpetrators and casualties can help law enforcement agencies develop strategies to respond to attacks involving multiple individuals. If attacks with more perpetrators are more lethal, it could inform decisions on resource deployment, tactical responses, and the level of force required to neutralize the threat.
#
# Intelligence Gathering: The negative correlation between the number of perpetrators and capture rates could highlight the need for improved intelligence gathering and surveillance techniques to track and apprehend larger groups involved in terrorist activities.
#
# Policy Making: The insights could inform policy decisions related to counterterrorism measures, such as stricter border control, enhanced surveillance, or community engagement programs to identify and disrupt potential threats.
#
# However, there are also potential negative growth implications to consider:
#
# Increased Security Costs: Acting on the insights might require increased investment in security measures, such as hiring more personnel, deploying advanced technology, or strengthening infrastructure. This could lead to higher costs for businesses and governments.
#
# Social and Economic Disruption: Increased security measures, particularly those targeting larger groups, could lead to profiling or discrimination, potentially alienating certain communities and disrupting social cohesion. This could have negative consequences for businesses operating in those areas.
#
# Escalation of Violence: Focusing solely on apprehending perpetrators without addressing the root causes of terrorism could lead to an escalation of violence and retaliatory attacks.
#
# Overall, the insights from the correlation heatmap can be valuable for informing decision-making and improving counterterrorism strategies. However, it's crucial to consider the broader social and economic implications and ensure that actions taken are proportionate, ethical, and contribute to long-term solutions.

# %% [markdown]
# #### Chart - 7 Combined plot that shows both univariate and bivariate analysis using a box plot with overlaid data points.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='attacktype1_txt', y='nkill', data=dataset)
sns.stripplot(x='attacktype1_txt', y='nkill', data=dataset, color='black', size=3, jitter=True)
plt.title('Distribution of Killed by Attack Type with Overlaid Data Points')
plt.xlabel('Attack Type')
plt.ylabel('Number of Killed')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose a box plot with overlaid data points for this univariate and bivariate analysis because:
#
# Combined Insights: This type of plot combines the strengths of both univariate and bivariate analysis. The box plot provides a summary of the distribution of the numerical variable ('nkill' in this case) for each category of the categorical variable ('attacktype1_txt'). The overlaid data points show the individual data points within each category, adding detail and allowing for the identification of potential outliers.
# Distribution and Variation: The box plot effectively visualizes the central tendency (median), spread (interquartile range), and potential outliers of the data. The overlaid data points enhance this by showing the density and distribution of individual data points within each box.
# Comparison Across Categories: The side-by-side nature of the box plot allows for easy comparison of the distribution of the numerical variable across different categories of the categorical variable. This helps identify differences in the number of people killed for various attack types.
# Data Type: This type of plot is suitable for visualizing the relationship between a numerical variable and a categorical variable, which is the case with 'nkill' and 'attacktype1_txt'.
# By using a box plot with overlaid data points, we can gain a comprehensive understanding of the distribution of casualties ('nkill') and how it varies across different attack types. This information can be valuable for understanding the impact of various attack methods and developing targeted countermeasures

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Variation in Casualties: You'll see how the number of people killed varies for different attack types. Some attack types, like bombings, might have a wider range of casualties and a higher median, indicating a greater potential for mass casualties.
# Outliers: The overlaid data points can help identify outliers, which are individual attacks with unusually high casualty numbers compared to the typical range for that attack type.
# Distribution Shape: The shape of the boxes and the position of the median within the box can indicate the skewness of the data. For example, a box plot with a longer tail on the higher end suggests that while most attacks of that type have fewer casualties, there are occasional instances with a very high number of deaths.
# Comparison Across Attack Types: You can compare the median, interquartile range, and overall distribution of casualties for different attack types to understand which methods are generally more lethal

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights from the box plot with overlaid data points can lead to a positive business impact, especially for security and law enforcement agencies:
#
# Targeted Resource Allocation: By understanding which attack types have the highest potential for casualties, resources can be allocated more effectively. This could involve investing in specialized training for first responders, developing more robust security protocols for potential targets, or increasing public awareness about the risks of certain attack types.
# Developing Countermeasures: The insights can help in developing targeted countermeasures against specific attack types. For example, if bombings are identified as causing high casualties, efforts could focus on disrupting the supply chain of explosives, enhancing bomb detection capabilities, and improving response strategies for mass casualty events.
# Risk Assessment and Mitigation: Businesses can use the information to assess the risk of different attack types and implement appropriate security measures. This could involve investing in security technologies, training staff on threat awareness, or developing emergency response plans.
# However, there are also potential downsides and negative growth implications:
#
# Focus on High-Impact Events: Overemphasizing high-casualty attack types could lead to neglecting other attack types that might be less lethal but still disruptive or damaging. Terrorist groups could adapt their tactics by shifting to different attack types if they perceive increased security measures in specific areas.
# Public Fear and Anxiety: Highlighting the deadliest attack types could create unnecessary fear and anxiety among the public, especially if not accompanied by clear communication about security measures and risk mitigation efforts.
# Misinterpretation of Outliers: Outliers in the data might represent exceptional circumstances or rare events. Focusing too heavily on outliers could lead to misallocation of resources or the development of countermeasures that are not effective against more typical attacks.
# Overall, the insights gained from this visualization can be valuable for informed decision-making and the development of effective counterterrorism strategies. However, it's essential to consider potential negative consequences, interpret the data cautiously, and maintain a balanced approach to address the multifaceted nature of terrorism

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on our analysis of the GTD dataset, we can suggest the following to our client to achieve the business objective of reducing global terrorism:
#
# Focus on the most frequent attack types: The most frequent attack type is bombing/explosion, followed by armed assault. The client should prioritize mitigating the risk of these types of attacks by:
# Increasing security measures around potential targets
# Implementing stricter control of explosives
# Developing better strategies to detect and respond to these types of attacks
# Understand the factors that contribute to successful attacks: The success rate of attacks varies depending on the attack type. The client should focus on understanding the factors that contribute to successful attacks and develop countermeasures accordingly. This may involve:
# Investing in intelligence gathering and analysis
# Improving security measures at potential targets
# Disrupting terrorist networks
# Consider the potential for negative growth: While focusing on preventing the most frequent and successful attack types, the client should also consider the potential for negative growth. This includes:
# Terrorist groups adapting their tactics in response to increased security measures
# The potential for attacks to displace to other areas or targets
# Address the root causes of terrorism: Terrorism is a complex phenomenon with a variety of root causes. The client should consider addressing these root causes in order to achieve a long-term reduction in global terrorism. This may involve:
# Promoting economic development and social justice
# Countering extremist ideologies
# Supporting conflict resolution and peacebuilding efforts
# By focusing on these areas, the client can work towards achieving the business objective of reducing global terrorism

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Based on our exploratory data analysis of the Global Terrorism Database, we can draw several conclusions:
#
# Bombing/Explosion is the most common attack type: This highlights the need for increased security measures and counter-terrorism strategies focusing on explosives and potential bomb targets.
# Armed assaults are also frequent and result in high casualties: This suggests a need for stricter gun control measures, improved intelligence gathering, and tactical response training for security personnel.
# Attack types have varying success rates: This indicates that different countermeasures may be needed for different types of attacks. Understanding the factors that contribute to successful attacks is crucial for developing effective prevention strategies.
# There is a correlation between the number of perpetrators and casualties: Attacks with more perpetrators tend to be more lethal, suggesting a need for strategies to address coordinated attacks and larger terrorist groups.
# Most attacks have a low number of casualties, but a few high-impact attacks cause significant devastation: This highlights the importance of both preventing smaller-scale attacks and mitigating the risk of mass-casualty events.
# The data can inform resource allocation and risk assessment: Understanding the patterns and trends in terrorist attacks can help organizations allocate resources effectively and make informed decisions about security measures.
# It's important to remember that these conclusions are based on your specific analysis of the dataset, and further investigation and analysis might reveal additional insights. The conclusions should be used to guide further research, policy decisions, and counter-terrorism strategies.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
